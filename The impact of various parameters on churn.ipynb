# %% [markdown]
# # The impact of Churn Rate by Monthly Charges and Tenure Segmentation where the customer does not have a Partner and Dependents, but chooses a long-term contract (One year and Two years)
#
# Money Charges Group :
#
# - low_charges : MonthlyCharges < 35.5
# - medium_charges : MonthlyCharges 35.5 - 89.85
# - high_charges : MonthlyCharges > 89.85 :
#
# Tenure Group :
#
# - low_tenure: < 21 Months
# - medium_tenure: 21 - 40 Months
# - high_tenure: > 40 Months

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.style as style

#your code goes here!
df = pd.read_csv(r'C:\Users\ASUS\Downloads\Hans On\WA_Fn-UseC_-Telco-Customer-Churn.csv')
df = df[['customerID','tenure','Contract','Dependents','Partner','MonthlyCharges','Churn']]
df
# Out:
#       customerID  tenure        Contract Dependents Partner  MonthlyCharges  \
# 0     7590-VHVEG       1  Month-to-month         No     Yes           29.85
# 1     5575-GNVDE      34        One year         No      No           56.95
# 2     3668-QPYBK       2  Month-to-month         No      No           53.85
# 3     7795-CFOCW      45        One year         No      No           42.30
# 4     9237-HQITU       2  Month-to-month         No      No           70.70
# ...          ...     ...             ...        ...     ...             ...
# 7038  6840-RESVB      24        One year        Yes     Yes           84.80
# 7039  2234-XADUH      72        One year        Yes     Yes          103.20
# 7040  4801-JZAZL      11  Month-to-month        Yes     Yes           29.60
# 7041  8361-LTMKD       4  Month-to-month         No     Yes           74.40
# 7042  3186-AJIEK      66        Two year         No      No          105.65
#
#      Churn
# 0       No
# 1       No
# 2      Yes
# ...

# %%
#Tenure Segmentation
df['Tenure Group'] = np.where(dfhard['tenure'] > 40, 'high_tenure',
                               np.where(dfhard['tenure'] > 21, 'medium_tenure', 'low_tenure'))
df
# Out:
#       customerID  tenure        Contract Dependents Partner  MonthlyCharges  \
# 0     7590-VHVEG       1  Month-to-month         No     Yes           29.85
# 1     5575-GNVDE      34        One year         No      No           56.95
# 2     3668-QPYBK       2  Month-to-month         No      No           53.85
# 3     7795-CFOCW      45        One year         No      No           42.30
# 4     9237-HQITU       2  Month-to-month         No      No           70.70
# ...          ...     ...             ...        ...     ...             ...
# 7038  6840-RESVB      24        One year        Yes     Yes           84.80
# 7039  2234-XADUH      72        One year        Yes     Yes          103.20
# 7040  4801-JZAZL      11  Month-to-month        Yes     Yes           29.60
# 7041  8361-LTMKD       4  Month-to-month         No     Yes           74.40
# 7042  3186-AJIEK      66        Two year         No      No          105.65
#
#      Churn   Tenure Group
# 0       No     low_tenure
# ...

# %%
#Contract Segmentation
df = df[df['Contract'].isin(['One year','Two year'])]
df
# Out:
#       customerID  tenure  Contract Dependents Partner  MonthlyCharges Churn  \
# 1     5575-GNVDE      34  One year         No      No           56.95    No
# 3     7795-CFOCW      45  One year         No      No           42.30    No
# 9     6388-TABGU      62  One year        Yes      No           56.15    No
# 11    7469-LKBCI      16  Two year         No      No           18.95    No
# 12    8091-TTVAX      58  One year         No     Yes          100.35    No
# ...          ...     ...       ...        ...     ...             ...   ...
# 7036  7750-EYXWZ      12  One year         No      No           60.65    No
# 7037  2569-WGERO      72  Two year         No      No           21.15    No
# 7038  6840-RESVB      24  One year        Yes     Yes           84.80    No
# 7039  2234-XADUH      72  One year        Yes     Yes          103.20    No
# 7042  3186-AJIEK      66  Two year         No      No          105.65    No
#
#        Tenure Group
# 1     medium_tenure
# ...

# %%
#Partner and Dependents Segmentation
df = df[(df['Partner'].isin(['No'])) & (df['Dependents'].isin(['No']))]
df
# Out:
#       customerID  tenure  Contract Dependents Partner  MonthlyCharges Churn  \
# 1     5575-GNVDE      34  One year         No      No           56.95    No
# 3     7795-CFOCW      45  One year         No      No           42.30    No
# 11    7469-LKBCI      16  Two year         No      No           18.95    No
# 16    8191-XWSZG      52  One year         No      No           20.65    No
# 43    4671-VJLCL      63  Two year         No      No           79.85    No
# ...          ...     ...       ...        ...     ...             ...   ...
# 7021  1699-HPSBG      12  One year         No      No           59.80   Yes
# 7022  7203-OYKCT      72  One year         No      No          104.95    No
# 7036  7750-EYXWZ      12  One year         No      No           60.65    No
# 7037  2569-WGERO      72  Two year         No      No           21.15    No
# 7042  3186-AJIEK      66  Two year         No      No          105.65    No
#
#        Tenure Group
# 1     medium_tenure
# ...

# %%
#Monthly Charges Segmentation
df['Monthly Charges Group'] = np.where(df['MonthlyCharges'] > 89.85, 'High MonthlyCharges',
                               np.where(df['MonthlyCharges'] > 35.5, 'Medium MonthlyCharges', 'Low MonthlyCharges'))
df
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_2116\261867017.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Monthly Charges Group'] = np.where(df['MonthlyCharges'] > 89.85, 'High MonthlyCharges',
#       customerID  tenure  Contract Dependents Partner  MonthlyCharges Churn  \
# 1     5575-GNVDE      34  One year         No      No           56.95    No
# 3     7795-CFOCW      45  One year         No      No           42.30    No
# 11    7469-LKBCI      16  Two year         No      No           18.95    No
# 16    8191-XWSZG      52  One year         No      No           20.65    No
# 43    4671-VJLCL      63  Two year         No      No           79.85    No
# ...

# %%
df['Churn'] = df['Churn'].map( {'No': 0, 'Yes': 1} ).astype(int)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_2116\895999349.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Churn'] = df['Churn'].map( {'No': 0, 'Yes': 1} ).astype(int)

# %%
result = pd.pivot_table(data=df, index='Tenure Group', columns='Monthly Charges Group',values='Churn')
result
# Out:
# Monthly Charges Group  High MonthlyCharges  Low MonthlyCharges  \
# Tenure Group
# high_tenure                       0.187192            0.019481
# low_tenure                        0.333333            0.009259
# medium_tenure                     0.088235            0.021505
#
# Monthly Charges Group  Medium MonthlyCharges
# Tenure Group
# high_tenure                         0.038298
# low_tenure                          0.117647
# medium_tenure                       0.111111

# %%
plt.figure(figsize = (10,5))
sns.heatmap(result, annot=True,cmap = sns.cubehelix_palette(as_cmap=True))
plt.xlabel('Monthly Charges Group', fontsize = 12)
plt.ylabel('Tenure Group', fontsize = 12)
plt.tick_params(axis = 'both', which = 'major', labelsize = 10)
plt.text(x=0, y=-0.8, s='How does the monthly charges group and tenure group affect churn?', fontsize=12, weight='bold')
plt.text(x=0, y=-0.5, s='The effect of Churn Rate on Monthly Charges and Tenure where customers', fontsize=12, alpha=0.75)
plt.text(x=0, y=-0.3, s='do not have Partner and Dependents, but choose long-term contracts', fontsize=12, alpha=0.75)
plt.text(x=0, y=-0.1, s='(One year and Two years contract)', fontsize=12, alpha=0.75)
plt.show()

# %% [markdown]
# ## ***The highest churn rate is for customers who have High Monthly Charges and Low Tenure, at 0.33, and the segmentation with the lowest churn rate is those who have Low Monthly Charges and Low Tenure, at 0.0093.***
